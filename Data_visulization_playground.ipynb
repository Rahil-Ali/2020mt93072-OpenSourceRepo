# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahil-Ali/2020mt93072-OpenSourceRepo/blob/main/Data_visulization_playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=1
print(a)
# Out:
# 1

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
'a'*3
# Out:
# 'aaa'

# %%
a = [1,2,3,4]
op = []
for i in a:
 op.append(i*i)
print(op)
# Out:
# [1, 4, 9, 16]

# %%
a = [1,2,3,4,5,6]

result = []

for i in a:
  if(i%2==0):
    result.append(i*i)
print(result)
# Out:
# [4, 16, 36]

# %%
result = [i*i for i in a if i%2==0]
print(result)
# Out:
# [4, 16, 36]

# %%
import math
p=3
b=4

h = math.hypot(p,b)
print(h)
# Out:
# 5.0

# %%
a=[10,20,30]
b=[1,2,3]

a/b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-d59422624aa9> in <module>()
#       2 b=[1,2,3]
#       3
# ----> 4 a/b
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %%
import numpy as np
a=np.array(a)
b=np.array(b)
a+b
# Out:
# array([11, 22, 33])

# %%
a+b
# Out:
# [10, 20, 30, 1, 2, 3]

# %%
import numpy as np
a = np.array([10,20,30])
a+5
# Out:
# array([15, 25, 35])

# %%
a=a+5
a
# Out:
# array([20, 30, 40])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %matplotlib inline # give me underline in this page itself

# %%
import seaborn as sns

iris = sns.load_dataset('iris')

type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
iris.tail(7)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.describe(include="object").T
# Out:
#         count unique        top freq
# species   150      3  virginica   50

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe(include="all").T
# Out:
#              count unique        top freq     mean  ...  min  25%   50%  75%  max
# sepal_length   150    NaN        NaN  NaN  5.84333  ...  4.3  5.1   5.8  6.4  7.9
# sepal_width    150    NaN        NaN  NaN  3.05733  ...    2  2.8     3  3.3  4.4
# petal_length   150    NaN        NaN  NaN    3.758  ...    1  1.6  4.35  5.1  6.9
# petal_width    150    NaN        NaN  NaN  1.19933  ...  0.1  0.3   1.3  1.8  2.5
# species        150      3  virginica   50      NaN  ...  NaN  NaN   NaN  NaN  NaN
#
# [5 rows x 11 columns]

# %%
iris['petal_bmi'] = iris['petal_length']/iris['petal_width']

iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  petal_bmi
# 0           5.1          3.5           1.4          0.2  setosa        7.0
# 1           4.9          3.0           1.4          0.2  setosa        7.0
# 2           4.7          3.2           1.3          0.2  setosa        6.5
# 3           4.6          3.1           1.5          0.2  setosa        7.5
# 4           5.0          3.6           1.4          0.2  setosa        7.0

# %%
iris.describe(include="object").T
# Out:
#         count unique        top freq
# species   150      3  virginica   50

# %%
# %reset -f # to delete all the variables: magic functions of jupyter notebook

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
# %pwd  # to execute linux commands
# Out:
# '/content'

# %%
# %%bash #collab can not install s/w directly. adding %%bash will enable collab interact with linux shell & execute supplied commands in bash

# %%
# %ls -lrt
# Out:
# total 4
# drwxr-xr-x 1 root root 4096 Aug 25 13:35 sample_data/

# %%
import matplotlib.pyplot as plt

# %%
sns.displot(data=iris,x="sepal_length")

# %%
iris.species.value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
sns.displot(data=iris,x="sepal_length",hue="species")

# %%
sns.displot(data=iris,x="sepal_length",col='species')

# %%
sns.displot(data=iris,x="sepal_length",col='species',binwidth=0.2)

# %%
sns.displot(data=iris,x="sepal_length",col='species',kind="kde",hue="species")

# %%
sns.displot(data=iris,x="sepal_length",col='species',binwidth=0.1,hue="species")

# %%
sns.displot(data=iris,x="sepal_length",hue="species",multiple='dodge')

# %%
sns.displot(data=iris,x="sepal_length",kind="kde",hue="species")

# %%
sns.catplot(x='species',y='sepal_length',data=iris,kind='box')

# %%
sns.catplot(x='species',y='sepal_length',data=iris,kind='violin')

# %%
iris.species.value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
iris[iris.species=='setosa']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
iris[iris.species=='setosa'].sepal_length
# Out:
# 0     5.1
# 1     4.9
# 2     4.7
# 3     4.6
# 4     5.0
# 5     5.4
# 6     4.6
# 7     5.0
# 8     4.4
# 9     4.9
# 10    5.4
# 11    4.8
# 12    4.8
# 13    4.3
# 14    5.8
# 15    5.7
# 16    5.4
# 17    5.1
# 18    5.7
# 19    5.1
# 20    5.4
# 21    5.1
# 22    4.6
# 23    5.1
# 24    4.8
# 25    5.0
# 26    5.0
# 27    5.2
# 28    5.2
# 29    4.7
# 30    4.8
# 31    5.4
# 32    5.2
# 33    5.5
# 34    4.9
# 35    5.0
# 36    5.5
# 37    4.9
# 38    4.4
# 39    5.1
# 40    5.0
# 41    4.5
# 42    4.4
# 43    5.0
# 44    5.1
# 45    4.8
# 46    5.1
# 47    4.6
# 48    5.3
# 49    5.0
# Name: sepal_length, dtype: float64

# %%
sns.relplot(data=iris,x='petal_length',y='petal_width',hue='species')

# %%
sns.relplot(data=iris,x='petal_length',y='petal_width',col='species')

# %%
sns.lineplot(data=iris,x='petal_length',y='petal_width',hue='species')

# %%
sns.pairplot(iris,hue='species')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
f,ax = plt.subplots(2,2, figsize=(18,8))
sns.boxplot(data=iris, x='species',y='sepal_length',ax=ax[0][0])
sns.violinplot(data=iris, x='species',y='sepal_length',ax=ax[0][1])
sns.kdeplot(data=iris, x='sepal_length',y='sepal_width',hue='species',ax=ax[1][0])
sns.scatterplot(data=iris, x='sepal_length',y='sepal_width',hue='species',ax=ax[1][1])
